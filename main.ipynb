# %% [markdown]
# # 📊 Sales Data Analytics Project
#
# Welcome to the Sales Data Analytics project!
#
# - For the complete, interactive exploratory analysis with charts and commentary, please see **[`notebooks/sales_analysis.ipynb`](notebooks/sales_analysis.ipynb)**.
# - For the automated end-to-end Python pipeline, run `python main.py`.
# - For the interactive web dashboard, run `streamlit run app.py`.
# - The original foundational NumPy proof-of-concept is archived in `legacy_main_numpy.py`.

# %%
# Run the complete analytics pipeline directly from this notebook:
import main
main.run_pipeline()
